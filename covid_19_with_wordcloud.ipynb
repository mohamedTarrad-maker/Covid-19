# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.express as px
import plotly.io as pio
pio.renderers.default='colab'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_csv('/content/covid+death.csv')
df.shape
# Out:
# (12260, 10)

# %%
df.head(10)
# Out:
#    Data as of  Start Week  ... Number of COVID-19 Deaths Flag
# 0  08/30/2020  02/01/2020  ...                     122.0  NaN
# 1  08/30/2020  02/01/2020  ...                     596.0  NaN
# 2  08/30/2020  02/01/2020  ...                    1521.0  NaN
# 3  08/30/2020  02/01/2020  ...                    4186.0  NaN
# 4  08/30/2020  02/01/2020  ...                   10014.0  NaN
# 5  08/30/2020  02/01/2020  ...                   16301.0  NaN
# 6  08/30/2020  02/01/2020  ...                   19091.0  NaN
# 7  08/30/2020  02/01/2020  ...                   19867.0  NaN
# 8  08/30/2020  02/01/2020  ...                       2.0  NaN
# 9  08/30/2020  02/01/2020  ...                   71700.0  NaN
#
# [10 rows x 10 columns]

# %%
df.tail(10)
# Out:
#        Data as of  ...                             Flag
# 12250  08/30/2020  ...                              NaN
# 12251  08/30/2020  ...                              NaN
# 12252  08/30/2020  ...                              NaN
# 12253  08/30/2020  ...                              NaN
# 12254  08/30/2020  ...                              NaN
# 12255  08/30/2020  ...                              NaN
# 12256  08/30/2020  ...                              NaN
# 12257  08/30/2020  ...                              NaN
# 12258  08/30/2020  ...  Counts less than 10 suppressed.
# 12259  08/30/2020  ...                              NaN
#
# [10 rows x 10 columns]

# %%
df.groupby(['Condition']).count()
# Out:
#                                                     Data as of  ...  Flag
# Condition                                                       ...
# Adult respiratory distress syndrome                        540  ...   268
# All other conditions and causes (residual)                 540  ...   177
# Alzheimer disease                                          530  ...   386
# COVID-19                                                   540  ...   163
# Cardiac arrest                                             520  ...   301
# Cardiac arrhythmia                                         540  ...   348
# Cerebrovascular diseases                                   530  ...   343
# Chronic lower respiratory diseases                         540  ...   311
# Diabetes                                                   540  ...   264
# Heart failure                                              540  ...   336
# Hypertensive diseases                                      540  ...   276
# ...

# %%
df.groupby(['Condition Group']).count()
# Out:
#                                                     Data as of  ...  Flag
# Condition Group                                                 ...
# All other conditions and causes (residual)                 540  ...   177
# Alzheimer disease                                          530  ...   386
# Circulatory diseases                                      3740  ...  2237
# Coronavirus Disease 2019                                   540  ...   163
# Diabetes                                                   540  ...   264
# Intentional and unintentional injury, poisoning...         520  ...   332
# Malignant neoplasms                                        540  ...   342
# Obesity                                                    530  ...   348
# Renal failure                                              540  ...   302
# Respiratory diseases                                      3180  ...  1729
# Sepsis                                                     530  ...   287
# ...

# %%
sentences=df['Condition'].tolist()
sentences_as_a_singlestring=' '.join(sentences)
plt.figure(figsize=(15,15))
plt.imshow(WordCloud().generate(sentences_as_a_singlestring))

# %%
sentences=df['Condition Group'].tolist()
sentences_as_a_singlestring=' '.join(sentences)
plt.figure(figsize=(15,15))
plt.imshow(WordCloud().generate(sentences_as_a_singlestring))
