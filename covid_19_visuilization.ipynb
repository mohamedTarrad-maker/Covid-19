# %% [markdown]
# # Importing  Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.express as px
import plotly.io as pio
pio.renderers.default='colab'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Imporing Dataset

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ed5d0301-9418-4f52-943c-1abd2d581ede" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed5d0301-9418-4f52-943c-1abd2d581ede">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covid.csv to covid.csv
# ...

# %%
df1=pd.read_csv('covid.csv')
df1.head()
# Out:
#   Country/Region      Continent  ...      WHO Region  iso_alpha
# 0            USA  North America  ...        Americas        USA
# 1         Brazil  South America  ...        Americas        BRA
# 2          India           Asia  ...  South-EastAsia        IND
# 3         Russia         Europe  ...          Europe        RUS
# 4   South Africa         Africa  ...          Africa        ZAF
#
# [5 rows x 17 columns]

# %%
df1.shape
# Out:
# (209, 17)

# %% [markdown]
# # Cleaning Data

# %%
total=df1.isnull().sum().sort_values(ascending=False)
percent=(df1.isnull().sum()/df1.isnull().count()).sort_values(ascending=False)
missing_values=pd.concat([total,percent],axis=1,keys=['Total','Percent'])
missing_values
# Out:
#                   Total   Percent
# NewRecovered        206  0.985646
# NewDeaths           206  0.985646
# NewCases            205  0.980861
# Serious,Critical     87  0.416268
# WHO Region           25  0.119617
# Deaths/1M pop        22  0.105263
# TotalDeaths          21  0.100478
# Tests/1M pop         18  0.086124
# TotalTests           18  0.086124
# ActiveCases           4  0.019139
# TotalRecovered        4  0.019139
# Population            1  0.004785
# Tot Cases/1M pop      1  0.004785
# Continent             1  0.004785
# iso_alpha             0  0.000000
# TotalCases            0  0.000000
# Country/Region        0  0.000000

# %%
df1.drop(['NewCases', 'NewDeaths','NewRecovered'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#   Country/Region      Continent  ...      WHO Region  iso_alpha
# 0            USA  North America  ...        Americas        USA
# 1         Brazil  South America  ...        Americas        BRA
# 2          India           Asia  ...  South-EastAsia        IND
# 3         Russia         Europe  ...          Europe        RUS
# 4   South Africa         Africa  ...          Africa        ZAF
#
# [5 rows x 14 columns]

# %%
from plotly.figure_factory import create_table
table=create_table(df1.head(10),colorscale='greens')
py.iplot(table)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5812e024-dbc9-4d1c-a05e-2558007fd6dd" class="plotly-graph-div" style="height:380px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5812e024-dbc9-4d1c-a05e-2558007fd6dd")) {
#                     Plotly.newPlot(
#                         '5812e024-dbc9-4d1c-a05e-2558007fd6dd',
# ...

# %%
df1.columns
# Out:
# Index(['Country/Region', 'Continent', 'Population', 'TotalCases',
#        'TotalDeaths', 'TotalRecovered', 'ActiveCases', 'Serious,Critical',
#        'Tot Cases/1M pop', 'Deaths/1M pop', 'TotalTests', 'Tests/1M pop',
#        'WHO Region', 'iso_alpha'],
#       dtype='object')

# %%
df1.shape
# Out:
# (209, 14)

# %% [markdown]
# # Creating Bar Plot

# %%
# Bar Plot
px.bar(df1.head(10),x='Country/Region',y='TotalCases',color='TotalCases',
       height=500,hover_data=['Country/Region','Continent'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="010ab828-10d2-4d8d-89d0-f9407b06f804" class="plotly-graph-div" style="height:500px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("010ab828-10d2-4d8d-89d0-f9407b06f804")) {
#                     Plotly.newPlot(
#                         '010ab828-10d2-4d8d-89d0-f9407b06f804',
# ...

# %%
# Bar Plot
px.bar(df1.head(10),x='Country/Region',y='TotalDeaths',color='Country/Region',
       height=500,hover_data=['Country/Region','Continent'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="986ea4d6-41ef-4c7b-813f-55e0bc1dcaec" class="plotly-graph-div" style="height:500px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("986ea4d6-41ef-4c7b-813f-55e0bc1dcaec")) {
#                     Plotly.newPlot(
#                         '986ea4d6-41ef-4c7b-813f-55e0bc1dcaec',
# ...

# %%
px.bar(df1.head(10),x='Country/Region',y='TotalRecovered',color='TotalRecovered',
       height=500,hover_data=['Country/Region','Continent'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="461f2edf-c02f-4384-a679-41ec878879dd" class="plotly-graph-div" style="height:500px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("461f2edf-c02f-4384-a679-41ec878879dd")) {
#                     Plotly.newPlot(
#                         '461f2edf-c02f-4384-a679-41ec878879dd',
# ...

# %%
px.bar(df1.head(10),x='TotalTests',y='Country/Region',color='TotalTests',
       height=500,orientation='h' ,
      hover_data=['Country/Region','Continent'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4f6df842-82ee-4a8d-9329-42955e9c7b89" class="plotly-graph-div" style="height:500px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4f6df842-82ee-4a8d-9329-42955e9c7b89")) {
#                     Plotly.newPlot(
#                         '4f6df842-82ee-4a8d-9329-42955e9c7b89',
# ...

# %%
px.bar(df1.head(10),x='TotalTests',y='Continent',color='TotalTests',
       height=500,orientation='h' ,
      hover_data=['Country/Region','Continent'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2b894e94-430e-4934-8d09-f969c75de714" class="plotly-graph-div" style="height:500px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2b894e94-430e-4934-8d09-f969c75de714")) {
#                     Plotly.newPlot(
#                         '2b894e94-430e-4934-8d09-f969c75de714',
# ...

# %% [markdown]
# # Scatter Plots

# %%
px.scatter(df1.head(12),x='Continent',y='TotalCases',color='TotalCases',
       size='TotalCases',size_max=100,
       hover_data=['Country/Region','Continent'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1862e7d9-1509-466d-b83c-b218b1ef9ae6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1862e7d9-1509-466d-b83c-b218b1ef9ae6")) {
#                     Plotly.newPlot(
#                         '1862e7d9-1509-466d-b83c-b218b1ef9ae6',
# ...

# %%
px.scatter(df1.head(50),x='Continent',y='TotalCases',color='TotalCases',
       size='TotalCases',size_max=100,log_y=True,
       hover_data=['Country/Region','Continent'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b96cfffc-fbe7-4946-aa1d-cac843edb0e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b96cfffc-fbe7-4946-aa1d-cac843edb0e0")) {
#                     Plotly.newPlot(
#                         'b96cfffc-fbe7-4946-aa1d-cac843edb0e0',
# ...

# %%
px.scatter(df1.head(50),x='Continent',y='TotalTests',color='TotalTests',
       size='TotalTests',size_max=100,
       hover_data=['Country/Region','Continent'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="fdcbd62c-121f-4c37-9455-ffe538e673f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fdcbd62c-121f-4c37-9455-ffe538e673f3")) {
#                     Plotly.newPlot(
#                         'fdcbd62c-121f-4c37-9455-ffe538e673f3',
# ...

# %%
px.scatter(df1.head(50),x='Continent',y='TotalTests',color='TotalTests',
       size='TotalTests',size_max=100,log_y=True,
       hover_data=['Country/Region','Continent'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0b300cd0-73c7-4508-8201-e224217482e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0b300cd0-73c7-4508-8201-e224217482e6")) {
#                     Plotly.newPlot(
#                         '0b300cd0-73c7-4508-8201-e224217482e6',
# ...

# %%
px.scatter(df1.head(50),x='Continent',y='TotalDeaths',color='TotalDeaths',
       size='TotalDeaths',size_max=100,log_y=True,
       hover_data=['Country/Region','Continent'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b10a601d-0a79-4bdf-b2d7-fea2dad054ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b10a601d-0a79-4bdf-b2d7-fea2dad054ea")) {
#                     Plotly.newPlot(
#                         'b10a601d-0a79-4bdf-b2d7-fea2dad054ea',
# ...

# %% [markdown]
# # Bubble Charts

# %%
px.scatter(df1.head(100),x='Country/Region',y='TotalCases',color='TotalCases',
       size='TotalCases',size_max=150,
       hover_data=['Country/Region','Continent'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a575db39-5606-4ec5-8447-a55677ec6c9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a575db39-5606-4ec5-8447-a55677ec6c9c")) {
#                     Plotly.newPlot(
#                         'a575db39-5606-4ec5-8447-a55677ec6c9c',
# ...

# %%
px.scatter(df1.head(30),x='Country/Region',y='TotalCases',color='Country/Region',
       size='TotalCases',size_max=150,log_y=True,
       hover_data=['Country/Region','Continent'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="155d143d-f41c-420b-a6dd-f07ac2aa09b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("155d143d-f41c-420b-a6dd-f07ac2aa09b5")) {
#                     Plotly.newPlot(
#                         '155d143d-f41c-420b-a6dd-f07ac2aa09b5',
# ...

# %%
px.scatter(df1.head(10),x='Country/Region',y='TotalDeaths',color='Country/Region',
       size='TotalDeaths',size_max=150,log_y=True,
       hover_data=['Country/Region','Continent'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="92321466-0a5c-43b6-83a8-2eca19b94991" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("92321466-0a5c-43b6-83a8-2eca19b94991")) {
#                     Plotly.newPlot(
#                         '92321466-0a5c-43b6-83a8-2eca19b94991',
# ...

# %%
px.scatter(df1.head(50),x='Country/Region',y='Deaths/1M pop',color='Country/Region',
       size='Deaths/1M pop',size_max=150,log_y=True,
       hover_data=['Country/Region','Continent'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="822497e3-f8d7-4ff0-8cf1-4243e279abb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("822497e3-f8d7-4ff0-8cf1-4243e279abb1")) {
#                     Plotly.newPlot(
#                         '822497e3-f8d7-4ff0-8cf1-4243e279abb1',
# ...

# %%
px.scatter(df1.head(10),x='Country/Region',y='Deaths/1M pop',color='Country/Region',
       size='Deaths/1M pop',size_max=150,log_y=True,
       hover_data=['Country/Region','Continent'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b61d33ab-9b70-4ae8-b18c-6a33a4c17381" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b61d33ab-9b70-4ae8-b18c-6a33a4c17381")) {
#                     Plotly.newPlot(
#                         'b61d33ab-9b70-4ae8-b18c-6a33a4c17381',
# ...

# %%
px.scatter(df1.head(50),x='Country/Region',y='TotalTests',color='Country/Region',
       size='TotalTests',size_max=150,log_y=True,
       hover_data=['Country/Region','Continent'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8ec6f7d0-a5b9-4469-870f-cd4b73b43247" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8ec6f7d0-a5b9-4469-870f-cd4b73b43247")) {
#                     Plotly.newPlot(
#                         '8ec6f7d0-a5b9-4469-870f-cd4b73b43247',
# ...

# %%
px.scatter(df1.head(20),x='Country/Region',y='Tests/1M pop',color='Country/Region',
       size='Tests/1M pop',size_max=150,log_y=True,
       hover_data=['Country/Region','Continent'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="afb04f38-bf18-4989-8b40-605db4766548" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("afb04f38-bf18-4989-8b40-605db4766548")) {
#                     Plotly.newPlot(
#                         'afb04f38-bf18-4989-8b40-605db4766548',
# ...

# %%
px.scatter(df1.head(30),x='Country/Region',y='Tests/1M pop',color='Tests/1M pop',
       size='Tests/1M pop',size_max=100,
       hover_data=['Country/Region','Continent'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="eeede98d-8199-47d9-813f-8cb28c2a29a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("eeede98d-8199-47d9-813f-8cb28c2a29a2")) {
#                     Plotly.newPlot(
#                         'eeede98d-8199-47d9-813f-8cb28c2a29a2',
# ...
